# %%
# %pip install scrapy
# %pip install scrapy-selenium
# %pip install selenium
# %pip install webdriver-manager
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# ...

# %%
variable = input(str("Please enter the linkedIn profile link you want to act as your main."))

if variable.__contains__("http"):
    print("This is a valid link")
else:
    print("This is not a valid link")
    variable = input(str("Please enter the linkedIn profile link you want to act as your main"))

print(variable)
# Out:
# This is not a valid link
# https://www.askpython.com/python/string/python-string-contains
